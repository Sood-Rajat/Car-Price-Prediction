# %% [markdown]
# # Car Price Prediction Project

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading Data

# %%
df = pd.read_csv("car_price_prediction.csv")
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  Yes    Hybrid           3.5  186005 km        6.0
# 1                   No    Petrol             3  192000 km        6.0
# 2                   No    Petrol           1.3  200000 km        4.0
# 3                  Yes    Hybrid           2.5  168966 km        4.0
# 4                  Yes    Petrol           1.3   91901 km        4.0
# ...                ...       ...           ...        ...        ...
# 19232              Yes       CNG     2.0 Turbo  300000 km        4.0
# 19233              Yes    Petrol           2.4  161600 km        4.0
# 19234              Yes    Diesel             2  116365 km        4.0
# 19235              Yes    Diesel             2   51258 km        4.0
# 19236              Yes    Hybrid           2.4  186923 km        4.0
#
#       Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0         Automatic          4x4  04-May        Left wheel  Silver       12
# 1         Tiptronic          4x4  04-May        Left wheel   Black        8
# 2          Variator        Front  04-May  Right-hand drive   Black        2
# 3         Automatic          4x4  04-May        Left wheel   White        0
# 4         Automatic        Front  04-May        Left wheel  Silver        4
# ...             ...          ...     ...               ...     ...      ...
# 19232        Manual         Rear  02-Mar        Left wheel  Silver        5
# 19233     Tiptronic        Front  04-May        Left wheel     Red        8
# 19234     Automatic        Front  04-May        Left wheel    Grey        4
# 19235     Automatic        Front  04-May        Left wheel   Black        4
# 19236     Automatic        Front  04-May        Left wheel   White       12
#
# [19237 rows x 18 columns]

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Checking null values in dataset

# %%
df.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %% [markdown]
# Checking total number of rows and columns in the dataset

# %%
df.shape
# Out:
# (19237, 18)

# %%
print(f"This DataSet Contains {df.shape[0]} rows & {df.shape[1]} columns")
# Out:
# This DataSet Contains 19237 rows & 18 columns

# %% [markdown]
# #### Checking datatype of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
#  16  Color             19237 non-null  object
#  17  Airbags           19237 non-null  int64
# dtypes: float64(1), int64(4), object(13)
# memory usage: 2.6+ MB

# %% [markdown]
# #### Describing the dataset

# %%
df.describe(include = "all").T
# Out:
#                     count unique         top   freq             mean  \
# ID                19237.0    NaN         NaN    NaN  45576535.886105
# Price             19237.0    NaN         NaN    NaN     18555.927224
# Levy                19237    559           -   5819              NaN
# Manufacturer        19237     65     HYUNDAI   3769              NaN
# Model               19237   1590       Prius   1083              NaN
# Prod. year        19237.0    NaN         NaN    NaN      2010.912824
# Category            19237     11       Sedan   8736              NaN
# Leather interior    19237      2         Yes  13954              NaN
# Fuel type           19237      7      Petrol  10150              NaN
# Engine volume       19237    107           2   3916              NaN
# Mileage             19237   7687        0 km    721              NaN
# Cylinders         19237.0    NaN         NaN    NaN         4.582991
# Gear box type       19237      4   Automatic  13514              NaN
# Drive wheels        19237      3       Front  12874              NaN
# Doors               19237      3      04-May  18332              NaN
# Wheel               19237      2  Left wheel  17753              NaN
# Color               19237     16       Black   5033              NaN
# Airbags           19237.0    NaN         NaN    NaN         6.582627
#
#                             std         min         25%         50%  \
# ID                936591.422799  20746880.0  45698374.0  45772308.0
# Price             190581.269684         1.0      5331.0     13172.0
# Levy                        NaN         NaN         NaN         NaN
# Manufacturer                NaN         NaN         NaN         NaN
# Model                       NaN         NaN         NaN         NaN
# Prod. year             5.668673      1939.0      2009.0      2012.0
# Category                    NaN         NaN         NaN         NaN
# Leather interior            NaN         NaN         NaN         NaN
# Fuel type                   NaN         NaN         NaN         NaN
# Engine volume               NaN         NaN         NaN         NaN
# Mileage                     NaN         NaN         NaN         NaN
# Cylinders              1.199933         1.0         4.0         4.0
# Gear box type               NaN         NaN         NaN         NaN
# Drive wheels                NaN         NaN         NaN         NaN
# Doors                       NaN         NaN         NaN         NaN
# Wheel                       NaN         NaN         NaN         NaN
# Color                       NaN         NaN         NaN         NaN
# Airbags                4.320168         0.0         4.0         6.0
#
#                          75%         max
# ID                45802036.0  45816654.0
# Price                22075.0  26307500.0
# Levy                     NaN         NaN
# Manufacturer             NaN         NaN
# Model                    NaN         NaN
# Prod. year            2015.0      2020.0
# Category                 NaN         NaN
# Leather interior         NaN         NaN
# Fuel type                NaN         NaN
# Engine volume            NaN         NaN
# Mileage                  NaN         NaN
# Cylinders                4.0        16.0
# Gear box type            NaN         NaN
# Drive wheels             NaN         NaN
# Doors                    NaN         NaN
# Wheel                    NaN         NaN
# Color                    NaN         NaN
# Airbags                 12.0        16.0

# %% [markdown]
# 1. The car price ranges from 1 t0 26307500 units.
# 2. The car production year starting from 1939 to 2020.
# 3. The most common car manufacturer in data is HYUNDAI.

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# #### Droping the duplicate values

# %%
df1 = df.drop_duplicates(keep = False)

# %% [markdown]
# #### Checking total number of rows and columns in the dataset after the droping of duplicate values

# %%
df1.shape
# Out:
# (18704, 18)

# %%
print(f"This DataSet Contains {df1.shape[0]} rows & {df1.shape[1]} columns after droping duplicate values")
# Out:
# This DataSet Contains 18704 rows & 18 columns after droping duplicate values

# %% [markdown]
# #### Checking the dataset after droping the duplicate values

# %%
df1.head(10)
# Out:
#           ID  Price  Levy   Manufacturer     Model  Prod. year   Category  \
# 0   45654403  13328  1399          LEXUS    RX 450        2010       Jeep
# 2   45774419   8467     -          HONDA       FIT        2006  Hatchback
# 3   45769185   3607   862           FORD    Escape        2011       Jeep
# 4   45809263  11726   446          HONDA       FIT        2014  Hatchback
# 5   45802912  39493   891        HYUNDAI  Santa FE        2016       Jeep
# 6   45656768   1803   761         TOYOTA     Prius        2010  Hatchback
# 7   45816158    549   751        HYUNDAI    Sonata        2013      Sedan
# 8   45641395   1098   394         TOYOTA     Camry        2014      Sedan
# 9   45756839  26657     -          LEXUS    RX 350        2007       Jeep
# 10  45621750    941  1053  MERCEDES-BENZ     E 350        2014      Sedan
#
#    Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0               Yes    Hybrid           3.5  186005 km        6.0
# 2                No    Petrol           1.3  200000 km        4.0
# 3               Yes    Hybrid           2.5  168966 km        4.0
# 4               Yes    Petrol           1.3   91901 km        4.0
# 5               Yes    Diesel             2  160931 km        4.0
# 6               Yes    Hybrid           1.8  258909 km        4.0
# 7               Yes    Petrol           2.4  216118 km        4.0
# 8               Yes    Hybrid           2.5  398069 km        4.0
# 9               Yes    Petrol           3.5  128500 km        6.0
# 10              Yes    Diesel           3.5  184467 km        6.0
#
#    Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0      Automatic          4x4  04-May        Left wheel  Silver       12
# 2       Variator        Front  04-May  Right-hand drive   Black        2
# 3      Automatic          4x4  04-May        Left wheel   White        0
# 4      Automatic        Front  04-May        Left wheel  Silver        4
# 5      Automatic        Front  04-May        Left wheel   White        4
# 6      Automatic        Front  04-May        Left wheel   White       12
# 7      Automatic        Front  04-May        Left wheel    Grey       12
# 8      Automatic        Front  04-May        Left wheel   Black       12
# 9      Automatic          4x4  04-May        Left wheel  Silver       12
# 10     Automatic         Rear  04-May        Left wheel   White       12

# %% [markdown]
# It is observed that after droping the duplicate values some values contain '-' symbol instead of datatypes.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18704 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18704 non-null  int64
#  1   Price             18704 non-null  int64
#  2   Levy              18704 non-null  object
#  3   Manufacturer      18704 non-null  object
#  4   Model             18704 non-null  object
#  5   Prod. year        18704 non-null  int64
#  6   Category          18704 non-null  object
#  7   Leather interior  18704 non-null  object
#  8   Fuel type         18704 non-null  object
#  9   Engine volume     18704 non-null  object
#  10  Mileage           18704 non-null  object
#  11  Cylinders         18704 non-null  float64
#  12  Gear box type     18704 non-null  object
#  13  Drive wheels      18704 non-null  object
#  14  Doors             18704 non-null  object
#  15  Wheel             18704 non-null  object
#  16  Color             18704 non-null  object
#  17  Airbags           18704 non-null  int64
# dtypes: float64(1), int64(4), object(13)
# memory usage: 2.7+ MB

# %% [markdown]
# #### Getting the columns which has dtypes objects

# %%
object_col = [col for col in df1.columns if df[col].dtype == 'object']
object_col
# Out:
# ['Levy',
#  'Manufacturer',
#  'Model',
#  'Category',
#  'Leather interior',
#  'Fuel type',
#  'Engine volume',
#  'Mileage',
#  'Gear box type',
#  'Drive wheels',
#  'Doors',
#  'Wheel',
#  'Color']

# %% [markdown]
# #### Changing some columns dtype from object to integer and float

# %%
df1["Levy"] = df1["Levy"].replace("-","0")

# %%
df1["Levy"] = df1["Levy"].astype("int64")

# %%
df1["Levy"]
# Out:
# 0        1399
# 2           0
# 3         862
# 4         446
# 5         891
#          ...
# 19232       0
# 19233     831
# 19234     836
# 19235    1288
# 19236     753
# Name: Levy, Length: 18704, dtype: int64

# %%
df1["Mileage"].head()
# Out:
# 0    186005 km
# 2    200000 km
# 3    168966 km
# 4     91901 km
# 5    160931 km
# Name: Mileage, dtype: object

# %%
df1["Mileage"] = df1["Mileage"].str.replace(" km"," ")

# %%
df1["Mileage"] = df1["Mileage"].astype("int64")

# %%
df1["Mileage"]
# Out:
# 0        186005
# 2        200000
# 3        168966
# 4         91901
# 5        160931
#           ...
# 19232    300000
# 19233    161600
# 19234    116365
# 19235     51258
# 19236    186923
# Name: Mileage, Length: 18704, dtype: int64

# %%
df1["Doors"].unique()
# Out:
# array(['04-May', '02-Mar', '>5'], dtype=object)

# %%
df1["Doors"] = df1["Doors"].str.replace("04-May", "4-5")
df1["Doors"] = df1["Doors"].str.replace("02-Mar", "2-5")

# %%
df1["Doors"].unique()
# Out:
# array(['4-5', '2-5', '>5'], dtype=object)

# %%
df1["Engine volume"].unique()
# Out:
# array(['3.5', '1.3', '2.5', '2', '1.8', '2.4', '4', '1.6', '3.3',
#        '2.0 Turbo', '2.2 Turbo', '4.7', '1.5', '3', '3.0 Turbo',
#        '1.4 Turbo', '3.6', '2.3', '1.5 Turbo', '1.6 Turbo', '2.2',
#        '2.3 Turbo', '1.4', '5.5', '2.8 Turbo', '3.2', '3.8', '4.6', '1.2',
#        '5', '1.7', '2.9', '0.5', '1.8 Turbo', '2.4 Turbo', '3.5 Turbo',
#        '1.9', '2.7', '4.8', '5.3', '0.4', '2.8', '3.2 Turbo', '1.1',
#        '2.1', '0.7', '5.4', '4.4', '1.3 Turbo', '3.7', '1', '2.5 Turbo',
#        '2.6', '1.9 Turbo', '4.4 Turbo', '4.7 Turbo', '0.8', '0.2 Turbo',
#        '5.7', '4.8 Turbo', '4.6 Turbo', '6.7', '6.2', '1.2 Turbo', '3.4',
#        '1.7 Turbo', '6.3 Turbo', '2.7 Turbo', '4.3', '4.2', '2.9 Turbo',
#        '0', '4.0 Turbo', '20', '3.6 Turbo', '0.3', '3.7 Turbo', '5.9',
#        '5.5 Turbo', '0.2', '2.1 Turbo', '5.6', '6', '0.7 Turbo',
#        '0.6 Turbo', '6.8', '4.5', '0.6', '7.3', '0.1', '1.0 Turbo', '6.3',
#        '4.5 Turbo', '0.8 Turbo', '4.2 Turbo', '3.1', '5.0 Turbo', '6.4',
#        '3.9', '5.7 Turbo', '0.9', '0.4 Turbo', '5.4 Turbo', '0.3 Turbo',
#        '5.2', '5.8', '1.1 Turbo'], dtype=object)

# %%
df1["Engine volume"] = df1["Engine volume"].str.replace("Turbo", "")

# %%
df1["Engine volume"] = df1["Engine volume"].astype("float64")

# %%
df1["Engine volume"]
# Out:
# 0        3.5
# 2        1.3
# 3        2.5
# 4        1.3
# 5        2.0
#         ...
# 19232    2.0
# 19233    2.4
# 19234    2.0
# 19235    2.0
# 19236    2.4
# Name: Engine volume, Length: 18704, dtype: float64

# %%
df1 = df1.drop("ID", axis = 1)

# %% [markdown]
# Since Id doesn't have an any kind of information needed for the dataset so we drop the column ID.

# %% [markdown]
# #### Checking of the Data after the cleaning

# %%
df1
# Out:
#        Price  Levy   Manufacturer     Model  Prod. year   Category  \
# 0      13328  1399          LEXUS    RX 450        2010       Jeep
# 2       8467     0          HONDA       FIT        2006  Hatchback
# 3       3607   862           FORD    Escape        2011       Jeep
# 4      11726   446          HONDA       FIT        2014  Hatchback
# 5      39493   891        HYUNDAI  Santa FE        2016       Jeep
# ...      ...   ...            ...       ...         ...        ...
# 19232   8467     0  MERCEDES-BENZ   CLK 200        1999      Coupe
# 19233  15681   831        HYUNDAI    Sonata        2011      Sedan
# 19234  26108   836        HYUNDAI    Tucson        2010       Jeep
# 19235   5331  1288      CHEVROLET   Captiva        2007       Jeep
# 19236    470   753        HYUNDAI    Sonata        2012      Sedan
#
#       Leather interior Fuel type  Engine volume  Mileage  Cylinders  \
# 0                  Yes    Hybrid            3.5   186005        6.0
# 2                   No    Petrol            1.3   200000        4.0
# 3                  Yes    Hybrid            2.5   168966        4.0
# 4                  Yes    Petrol            1.3    91901        4.0
# 5                  Yes    Diesel            2.0   160931        4.0
# ...                ...       ...            ...      ...        ...
# 19232              Yes       CNG            2.0   300000        4.0
# 19233              Yes    Petrol            2.4   161600        4.0
# 19234              Yes    Diesel            2.0   116365        4.0
# 19235              Yes    Diesel            2.0    51258        4.0
# 19236              Yes    Hybrid            2.4   186923        4.0
#
#       Gear box type Drive wheels Doors             Wheel   Color  Airbags
# 0         Automatic          4x4   4-5        Left wheel  Silver       12
# 2          Variator        Front   4-5  Right-hand drive   Black        2
# 3         Automatic          4x4   4-5        Left wheel   White        0
# 4         Automatic        Front   4-5        Left wheel  Silver        4
# 5         Automatic        Front   4-5        Left wheel   White        4
# ...             ...          ...   ...               ...     ...      ...
# 19232        Manual         Rear   2-5        Left wheel  Silver        5
# 19233     Tiptronic        Front   4-5        Left wheel     Red        8
# 19234     Automatic        Front   4-5        Left wheel    Grey        4
# 19235     Automatic        Front   4-5        Left wheel   Black        4
# 19236     Automatic        Front   4-5        Left wheel   White       12
#
# [18704 rows x 17 columns]

# %% [markdown]
# • Here, Price column is the target variable in the dataset.
#
# • And all other columns are the independent variable in the dataset.

# %% [markdown]
# ## Visualization

# %%
for col in df1.select_dtypes(include = "object" ):
    print(f'The value count of the {col} is: \n\n {df1[col].value_counts()} \n\n')
# Out:
# The value count of the Manufacturer is:
#
#  HYUNDAI          3690
# TOYOTA           3563
# MERCEDES-BENZ    2019
# FORD             1075
# BMW              1027
#                  ...
# TESLA               1
# PONTIAC             1
# SATURN              1
# ASTON MARTIN        1
# GREATWALL           1
# Name: Manufacturer, Length: 65, dtype: int64
#
#
# The value count of the Model is:
#
#  Sonata                   1056
# Prius                    1055
# Camry                     921
# Elantra                   898
# E 350                     530
#                          ...
# C-MAX C-MAX                 1
# X1 4X4                      1
# Land Cruiser Prado RX       1
# 456                         1
# Prius C aqua                1
# Name: Model, Length: 1579, dtype: int64
#
#
# The value count of the Category is:
#
#  Sedan          8492
# Jeep           5315
# Hatchback      2771
# Minivan         627
# Coupe           524
# Universal       358
# Microbus        296
# Goods wagon     226
# Pickup           50
# Cabriolet        34
# Limousine        11
# Name: Category, dtype: int64
#
#
# The value count of the Leather interior is:
#
#  Yes    13563
# No      5141
# Name: Leather interior, dtype: int64
#
#
# The value count of the Fuel type is:
#
#  Petrol            9803
# Diesel            3971
# Hybrid            3507
# LPG                878
# CNG                460
# Plug-in Hybrid      84
# Hydrogen             1
# Name: Fuel type, dtype: int64
#
#
# The value count of the Gear box type is:
#
#  Automatic    13116
# Tiptronic     3034
# Manual        1828
# Variator       726
# Name: Gear box type, dtype: int64
#
#
# The value count of the Drive wheels is:
#
#  Front    12553
# 4x4       3922
# Rear      2229
# Name: Drive wheels, dtype: int64
#
#
# The value count of the Doors is:
#
#  4-5    17822
# 2-5      759
# >5       123
# Name: Doors, dtype: int64
#
#
# The value count of the Wheel is:
#
#  Left wheel          17266
# Right-hand drive     1438
# Name: Wheel, dtype: int64
#
#
# The value count of the Color is:
#
#  Black            4889
# White            4349
# Silver           3681
# Grey             2319
# Blue             1362
# Red               611
# Green             320
# Orange            251
# Brown             183
# Carnelian red     175
# Golden            141
# Beige             134
# Sky blue          122
# Yellow            104
# Purple             39
# Pink               24
# Name: Color, dtype: int64

# %% [markdown]
# ### Analyzing fuel type used in the cars

# %%
df1["Fuel type"].unique()
# Out:
# array(['Hybrid', 'Petrol', 'Diesel', 'CNG', 'Plug-in Hybrid', 'LPG',
#        'Hydrogen'], dtype=object)

# %%
fuelcounts = df1["Fuel type"].value_counts()
fuelcounts
# Out:
# Petrol            9803
# Diesel            3971
# Hybrid            3507
# LPG                878
# CNG                460
# Plug-in Hybrid      84
# Hydrogen             1
# Name: Fuel type, dtype: int64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8,4))
sns.barplot(x = fuelcounts.index, y = fuelcounts, data = df1)
plt.xlabel("Fuel Type")
plt.ylabel("Number of cars")
plt.show()

# %% [markdown]
# • The fuel type of petrol has maximum number of cars i.e 9803.
#
# • And the fuel type of Hydrogen has least number of cars i.e 1.

# %% [markdown]
# ### Analyzing that the car contains leather interior or not

# %%
df1["Leather interior"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
Leather_interior = df1["Leather interior"].value_counts()
Leather_interior
# Out:
# Yes    13563
# No      5141
# Name: Leather interior, dtype: int64

# %%
sns.set_style('whitegrid')
sns.countplot(x = "Leather interior" , data = df1)
plt.title("No. of cars having Leather Interior")
plt.xlabel("Leather Interior")
plt.ylabel("No. of cars")
plt.show()

# %%
labels = ['Yes', 'No']
plt.pie(Leather_interior, autopct = "%1.2f%%", labels = labels)
plt.title("Leather interior or not")
plt.show()

# %% [markdown]
# On the basis of the pie plot we can see that around 72.51% cars have leather interiors.

# %% [markdown]
# ### Analyzing of different types of gear boxes used in the car

# %%
gearbox =  df1["Gear box type"].value_counts()
gearbox
# Out:
# Automatic    13116
# Tiptronic     3034
# Manual        1828
# Variator       726
# Name: Gear box type, dtype: int64

# %%
plt.pie(gearbox, autopct = "%1.2f%%", labels = gearbox.index)
plt.title("Different types of Gearboxes")
plt.show()

# %% [markdown]
# • We Analyze that 70.12% of Automatic type Gearboxes are installed in the car.
#
# • We Analyze that 16.22% of Tiptronic type Gearboxes are installed in the car.
#
# • We Analyze that 9.77% of Manual type Gearboxes are installed in the car.
#
# • We Analyze that 3.88% of Variator type Gearboxes are installed in the car.

# %%
sns.barplot(x = gearbox.index,y = gearbox, data = df1)
plt.xlabel("Gear Box Type")
plt.ylabel("Number of Cars")
plt.show()

# %% [markdown]
# • 13,116 vehicles have a Automatic gearbox.
#
# • 3,034 vehicles have a Tiptronic gearbox.
#
# • 1,828 vehicles have a Manual gearbox.
#
# • 726 vehicles have a Variator gearbox.

# %% [markdown]
# ### Analyzing Top 20 Car Manufacturers

# %%
df1["Manufacturer"].value_counts()
# Out:
# HYUNDAI          3690
# TOYOTA           3563
# MERCEDES-BENZ    2019
# FORD             1075
# BMW              1027
#                  ...
# TESLA               1
# PONTIAC             1
# SATURN              1
# ASTON MARTIN        1
# GREATWALL           1
# Name: Manufacturer, Length: 65, dtype: int64

# %%
manufacture = df1["Manufacturer"].value_counts().head(20)
manufacture
# Out:
# HYUNDAI          3690
# TOYOTA           3563
# MERCEDES-BENZ    2019
# FORD             1075
# BMW              1027
# CHEVROLET        1026
# HONDA             949
# LEXUS             903
# NISSAN            636
# VOLKSWAGEN        566
# SSANGYONG         437
# KIA               413
# OPEL              395
# MITSUBISHI        287
# SUBARU            273
# AUDI              253
# MAZDA             173
# JEEP              138
# DAEWOO             91
# DODGE              89
# Name: Manufacturer, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.set_style("darkgrid")
a = sns.barplot(x = manufacture.index,y = manufacture, data = df1);
a.set_xticklabels(manufacture.index ,rotation=90)
a.set(xlabel='Car Manufacturer', ylabel='Number of Cars')
plt.title("Number of cars Produced by the the top 20 Car Manufacturers")
plt.show()

# %% [markdown]
# • Hyundai produced the maximum no. of cars and they are on the no. 1 position on producing the cars.
#
# • Dodge produced the least no. of cars and they are on the no. 20 position on producing the cars.

# %% [markdown]
# ### Analyzing the car on the basis of their Category i.e Body type

# %%
car_category = df1["Category"].value_counts()
car_category
# Out:
# Sedan          8492
# Jeep           5315
# Hatchback      2771
# Minivan         627
# Coupe           524
# Universal       358
# Microbus        296
# Goods wagon     226
# Pickup           50
# Cabriolet        34
# Limousine        11
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(14,7))
sns.set_style("darkgrid")
a = sns.barplot(x = car_category.index,y = car_category, data = df1);
a.set_xticklabels(car_category.index ,rotation=90)
a.set(xlabel='Category/Body Type Name', ylabel='Number of Cars')
plt.title("Number of cars in each Category")
plt.show()

# %% [markdown]
# • Sedan Category has maximum number of cars.
#
# • Limousine Category has least number of cars.

# %% [markdown]
# ### Analyzing  the Yearly Car Production

# %%
df1["Prod. year"].value_counts()
# Out:
# 2012    2110
# 2014    2062
# 2013    1886
# 2011    1558
# 2015    1510
# 2010    1450
# 2016    1430
# 2017     925
# 2008     725
# 2009     589
# 2018     483
# 2007     456
# 2005     393
# 2003     355
# 2004     349
# 2006     313
# 2019     302
# 2002     282
# 2000     275
# 2001     252
# 1999     203
# 1998     202
# 1997     151
# 1996     108
# 1995     100
# 2020      47
# 1994      40
# 1992      30
# 1993      23
# 1990      18
# 1988      12
# 1991      10
# 1989       6
# 1986       6
# 1987       5
# 1985       5
# 1984       5
# 1953       4
# 1983       3
# 1939       3
# 1964       2
# 1977       2
# 1978       2
# 1965       2
# 1980       2
# 1947       1
# 1981       1
# 1982       1
# 1943       1
# 1968       1
# 1957       1
# 1976       1
# 1973       1
# Name: Prod. year, dtype: int64

# %%
plt.figure(figsize=(15,12))
sns.countplot(x = "Prod. year", data = df1)
plt.xlabel("Production Year")
plt.ylabel("No. of Cars")
plt.title("No. of Cars Produced Yearly")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# In Year 2012 maximum number of cars is produced.

# %% [markdown]
# ### Analysis of Engine Volume

# %%
df1["Engine volume"].value_counts()
# Out:
# 2.0    4206
# 2.5    2313
# 1.8    1899
# 1.6    1546
# 1.5    1331
#        ...
# 0.5       1
# 7.3       1
# 3.1       1
# 5.2       1
# 5.8       1
# Name: Engine volume, Length: 65, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(x = "Engine volume", data = df1)
plt.xlabel("Engine Volume")
plt.ylabel("No. of Cars")
plt.title("No. of Cars vs Engine Volume")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Majority of the car produced 2L Engine volume.

# %% [markdown]
# ### Analyzing of the Mileage

# %%
df1["Mileage"].value_counts()
# Out:
# 0         712
# 200000    179
# 150000    157
# 160000    120
# 180000    116
#          ...
# 45220       1
# 99653       1
# 392000      1
# 160008      1
# 186923      1
# Name: Mileage, Length: 7586, dtype: int64

# %%
mileage = df1["Mileage"].value_counts().head(25)
mileage
# Out:
# 0         712
# 200000    179
# 150000    157
# 160000    120
# 180000    116
# 100000    102
# 170000     99
# 120000     98
# 1000       98
# 130000     83
# 111111     80
# 140000     71
# 190000     68
# 300000     67
# 250000     67
# 145000     63
# 110000     61
# 80000      60
# 220000     59
# 240000     59
# 90000      58
# 135000     55
# 112000     53
# 125000     52
# 95000      50
# Name: Mileage, dtype: int64

# %%
plt.figure(figsize=(14,7))
a = sns.barplot(x = mileage.index,y = mileage, data = df1);
a.set_xticklabels(mileage.index ,rotation=90)
a.set(xlabel='Mileage', ylabel='Number of Cars')
plt.title("Number of cars Mileage(in km)")
plt.show()

# %% [markdown]
# Most no. of cars are having the mileage 0 km.

# %% [markdown]
#  ### Analysis on the Airbags

# %%
plt.figure(figsize=(14,7))
sns.histplot(x = df1["Airbags"])
plt.show()

# %% [markdown]
# • Here count is no. of cars.
#
# • It tells us that minimum 4 airbags are installed in the cars.

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x = df1["Airbags"])
plt.show()

# %% [markdown]
# • It tells us that minimum 4 airbags are installed in the car.
#
# • It tells us that avg. 6 airbags are installed in the car.
#
# • It tells us that maximum 12 airbags are installed in the car.

# %% [markdown]
# ### Checking relationship of the columns

# %%
plt.figure(figsize=(16,14))
sns.heatmap(df1.corr(), annot = True, cmap = "Reds")
plt.show()

# %% [markdown]
# ### Handeling with the outliers

# %%
for col in df1.select_dtypes(exclude = "object" ):
    plt.figure(figsize=(12,7))
    plt.subplot(1,2,1)
    sns.distplot(x = df1[col]);
    plt.title(f'The DistPlot for the {col} ')
    plt.subplot(1,2,2)
    sns.boxplot(x = df1[col]);
    plt.title(f'The BoxPlot for the {col} ')
    plt.suptitle(f'{col.title()} (Before handling outliers)',weight='bold')
    plt.show()

# %% [markdown]
# Here, We can see that there are too many outliers in our dataset due to this we can't visualize the distplot & boxplot. These outliers are influencing the data distribution and making it challenging to draw meaningful conclusions from the visualizations.

# %% [markdown]
# ### Checking number and percentage of the outliers present in our dataset.

# %%
def outlier_prcnt(data):
    for col_name in data.select_dtypes(exclude="object"):
        q1 = data[col_name].quantile(0.25)
        q3 = data[col_name].quantile(0.75)
        iqr = q3 - q1  
        fence_low = q1 - 1.5 * iqr
        fence_high = q3 + 1.5 * iqr

        outliers = ((data[col_name] > fence_high) | (data[col_name] < fence_low)).sum()
        total = data[col_name].shape[0]
        print(f"Total outliers in {col_name} are: {outliers} - {round(100 * (outliers) / total, 2)}%.")

outlier_prcnt(df1)
# Out:
# Total outliers in Price are: 1088 - 5.82%.
# Total outliers in Levy are: 159 - 0.85%.
# Total outliers in Prod. year are: 952 - 5.09%.
# Total outliers in Engine volume are: 1339 - 7.16%.
# Total outliers in Mileage are: 611 - 3.27%.
# Total outliers in Cylinders are: 4706 - 25.16%.
# Total outliers in Airbags are: 0 - 0.0%.

# %%
def outlier_handle(data):
    df1_copy = df1.copy()
    for col_name in data.select_dtypes(exclude="object"):
        q1 = data[col_name].quantile(0.25)
        q3 = data[col_name].quantile(0.75)
        iqr = q3-q1  #IQR
        fence_low  = q1-1.5*iqr
        fence_high = q3+1.5*iqr
        df1_copy.loc[:,  col_name] = np.where(data[col_name]> fence_high, fence_high,
                                         np.where(data[col_name]< fence_low, fence_low,
                                                  data[col_name]))
    return df1_copy
df1 = outlier_handle(df1)

# %%
for col in df1.select_dtypes(exclude = "object" ):
    plt.figure(figsize=(12,7))
    plt.subplot(1,2,1)
    sns.distplot(x = df1[col]);
    plt.title(f'The DistPlot for the {col} ')
    plt.subplot(1,2,2)
    sns.boxplot(x = df1[col]);
    plt.title(f'The BoxPlot for the {col} ')
    plt.suptitle(f'{col.title()} (After handling outliers)',weight='bold')
    plt.show()

# %%
plt.figure(figsize=(15,15))
sns.pairplot(df1)
plt.show()

# %% [markdown]
# ### Handeling outliers on skewness of Price columns

# %%
sns.distplot(df1['Price'], label = 'Skewness: %.2f'%(df1['Price'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the Price column')
plt.show()

# %% [markdown]
# ### Encoding

# %%
new_df = df1

# %%
from sklearn.preprocessing import LabelEncoder
Manufacturer_le = LabelEncoder()
Model_le = LabelEncoder()
Category_le = LabelEncoder()
Leather_interior_le = LabelEncoder()
Fuel_type_le = LabelEncoder()
Gear_box_type_le = LabelEncoder()
Doors_le  = LabelEncoder()
Wheel_le  = LabelEncoder() 
Drive_wheels_le = LabelEncoder() 
color_le = LabelEncoder()

# %%
new_df['Manufacturer'] = Manufacturer_le.fit_transform(new_df['Manufacturer'])
new_df['Model'] = Model_le.fit_transform(new_df['Model'])
new_df['Category'] = Category_le.fit_transform(new_df['Category'])
new_df['Leather interior'] = Leather_interior_le.fit_transform(new_df['Leather interior'])
new_df['Fuel type'] = Fuel_type_le.fit_transform(new_df['Fuel type'])
new_df['Gear box type'] = Gear_box_type_le.fit_transform(new_df['Gear box type'])
new_df['Doors'] = Doors_le.fit_transform(new_df['Doors'])
new_df['Wheel'] = Wheel_le.fit_transform(new_df['Wheel'])
new_df['Drive wheels'] = Drive_wheels_le.fit_transform(new_df['Drive wheels'])

# %%
new_df = new_df.drop("Color", axis = 1)

# %%
new_df["Price"] = new_df["Price"] + new_df["Levy"]

# %%
new_df = new_df.drop("Levy", axis = 1)

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# ### Linear Regression Model

# %%
new_df
# Out:
#          Price  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0      14727.0            32   1234      2010.0         4                 1
# 2       8467.0            21    679      2006.0         3                 0
# 3       4469.0            16    656      2011.0         4                 1
# 4      12172.0            21    679      2014.0         3                 1
# 5      40384.0            23   1297      2016.0         4                 1
# ...        ...           ...    ...         ...       ...               ...
# 19232   8467.0            36    384      2000.0         1                 1
# 19233  16512.0            23   1326      2011.0         9                 1
# 19234  26944.0            23   1433      2010.0         4                 1
# 19235   6619.0             8    455      2007.0         4                 1
# 19236   1223.0            23   1326      2012.0         9                 1
#
#        Fuel type  Engine volume   Mileage  Cylinders  Gear box type  \
# 0              2            3.5  186005.0        4.0              0
# 2              5            1.3  200000.0        4.0              3
# 3              2            2.5  168966.0        4.0              0
# 4              5            1.3   91901.0        4.0              0
# 5              1            2.0  160931.0        4.0              0
# ...          ...            ...       ...        ...            ...
# 19232          0            2.0  300000.0        4.0              1
# 19233          5            2.4  161600.0        4.0              2
# 19234          1            2.0  116365.0        4.0              0
# 19235          1            2.0   51258.0        4.0              0
# 19236          2            2.4  186923.0        4.0              0
#
#        Drive wheels  Doors  Wheel  Airbags
# 0                 0      1      0     12.0
# 2                 1      1      1      2.0
# 3                 0      1      0      0.0
# 4                 1      1      0      4.0
# 5                 1      1      0      4.0
# ...             ...    ...    ...      ...
# 19232             2      0      0      5.0
# 19233             1      1      0      8.0
# 19234             1      1      0      4.0
# 19235             1      1      0      4.0
# 19236             1      1      0     12.0
#
# [18704 rows x 15 columns]

# %% [markdown]
# #### Splitting the Target and Data

# %%
X = new_df.iloc[:,1:]
Y = new_df['Price']

# %%
print(X)
# Out:
#        Manufacturer  Model  Prod. year  Category  Leather interior  Fuel type  \
# 0                32   1234      2010.0         4                 1          2
# 2                21    679      2006.0         3                 0          5
# 3                16    656      2011.0         4                 1          2
# 4                21    679      2014.0         3                 1          5
# 5                23   1297      2016.0         4                 1          1
# ...             ...    ...         ...       ...               ...        ...
# 19232            36    384      2000.0         1                 1          0
# 19233            23   1326      2011.0         9                 1          5
# 19234            23   1433      2010.0         4                 1          1
# 19235             8    455      2007.0         4                 1          1
# 19236            23   1326      2012.0         9                 1          2
#
#        Engine volume   Mileage  Cylinders  Gear box type  Drive wheels  Doors  \
# 0                3.5  186005.0        4.0              0             0      1
# 2                1.3  200000.0        4.0              3             1      1
# 3                2.5  168966.0        4.0              0             0      1
# 4                1.3   91901.0        4.0              0             1      1
# 5                2.0  160931.0        4.0              0             1      1
# ...              ...       ...        ...            ...           ...    ...
# 19232            2.0  300000.0        4.0              1             2      0
# 19233            2.4  161600.0        4.0              2             1      1
# 19234            2.0  116365.0        4.0              0             1      1
# 19235            2.0   51258.0        4.0              0             1      1
# 19236            2.4  186923.0        4.0              0             1      1
#
#        Wheel  Airbags
# 0          0     12.0
# 2          1      2.0
# 3          0      0.0
# 4          0      4.0
# 5          0      4.0
# ...      ...      ...
# 19232      0      5.0
# 19233      0      8.0
# 19234      0      4.0
# 19235      0      4.0
# 19236      0     12.0
#
# [18704 rows x 14 columns]

# %%
print(Y)
# Out:
# 0        14727.0
# 2         8467.0
# 3         4469.0
# 4        12172.0
# 5        40384.0
#           ...
# 19232     8467.0
# 19233    16512.0
# 19234    26944.0
# 19235     6619.0
# 19236     1223.0
# Name: Price, Length: 18704, dtype: float64

# %% [markdown]
# #### Splitting the Training and Test data

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X,Y , test_size= 0.25 ,random_state=42)

# %%
print("x_train =", x_train.shape)
print("x_test =", x_test.shape)
print()
print("y_train =", y_train.shape)
print("y_test =", y_test.shape)
# Out:
# x_train = (14028, 14)
# x_test = (4676, 14)
#
# y_train = (14028,)
# y_test = (4676,)

# %% [markdown]
# Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test  = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()
linear_regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_regressor.predict(x_test)
lr = pd.DataFrame({'y_test':y_test,'y_pred':y_pred})
lr.head()
# Out:
#         y_test        y_pred
# 60     17465.0  19970.510531
# 4640   31389.0  25821.642966
# 2751   15551.0  12513.962677
# 13879  13891.0  14946.315627
# 15200  10171.0  15890.120484

# %% [markdown]
# #### Evaluation

# %%
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
mae = round(mean_absolute_error(y_test, y_pred), 3)
mse = round(mean_squared_error(y_test, y_pred), 3)
rmse = round(np.sqrt(mse), 3)

r2_value = round(r2_score(y_test, y_pred), 3)

print('Mean Absolute Error  of the model is : {}'.format(mae))
print('Mean Squared Error of the model is : {}'.format(mse))
print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
# Out:
# Mean Absolute Error  of the model is : 9022.291
# Mean Squared Error of the model is : 132948378.935
# Root Mean Squared Error of the model is : 11530.324
# R-squared value of the model is : 0.262

# %% [markdown]
# ### Logistic Regression Model

# %%
new_df
# Out:
#          Price  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0      14727.0            32   1234      2010.0         4                 1
# 2       8467.0            21    679      2006.0         3                 0
# 3       4469.0            16    656      2011.0         4                 1
# 4      12172.0            21    679      2014.0         3                 1
# 5      40384.0            23   1297      2016.0         4                 1
# ...        ...           ...    ...         ...       ...               ...
# 19232   8467.0            36    384      2000.0         1                 1
# 19233  16512.0            23   1326      2011.0         9                 1
# 19234  26944.0            23   1433      2010.0         4                 1
# 19235   6619.0             8    455      2007.0         4                 1
# 19236   1223.0            23   1326      2012.0         9                 1
#
#        Fuel type  Engine volume   Mileage  Cylinders  Gear box type  \
# 0              2            3.5  186005.0        4.0              0
# 2              5            1.3  200000.0        4.0              3
# 3              2            2.5  168966.0        4.0              0
# 4              5            1.3   91901.0        4.0              0
# 5              1            2.0  160931.0        4.0              0
# ...          ...            ...       ...        ...            ...
# 19232          0            2.0  300000.0        4.0              1
# 19233          5            2.4  161600.0        4.0              2
# 19234          1            2.0  116365.0        4.0              0
# 19235          1            2.0   51258.0        4.0              0
# 19236          2            2.4  186923.0        4.0              0
#
#        Drive wheels  Doors  Wheel  Airbags
# 0                 0      1      0     12.0
# 2                 1      1      1      2.0
# 3                 0      1      0      0.0
# 4                 1      1      0      4.0
# 5                 1      1      0      4.0
# ...             ...    ...    ...      ...
# 19232             2      0      0      5.0
# 19233             1      1      0      8.0
# 19234             1      1      0      4.0
# 19235             1      1      0      4.0
# 19236             1      1      0     12.0
#
# [18704 rows x 15 columns]

# %% [markdown]
# #### Splitting the Target and Data

# %%
X = new_df.iloc[:,1:-3]
Y = new_df["Wheel"]

# %%
X
# Out:
#        Manufacturer  Model  Prod. year  Category  Leather interior  Fuel type  \
# 0                32   1234      2010.0         4                 1          2
# 2                21    679      2006.0         3                 0          5
# 3                16    656      2011.0         4                 1          2
# 4                21    679      2014.0         3                 1          5
# 5                23   1297      2016.0         4                 1          1
# ...             ...    ...         ...       ...               ...        ...
# 19232            36    384      2000.0         1                 1          0
# 19233            23   1326      2011.0         9                 1          5
# 19234            23   1433      2010.0         4                 1          1
# 19235             8    455      2007.0         4                 1          1
# 19236            23   1326      2012.0         9                 1          2
#
#        Engine volume   Mileage  Cylinders  Gear box type  Drive wheels
# 0                3.5  186005.0        4.0              0             0
# 2                1.3  200000.0        4.0              3             1
# 3                2.5  168966.0        4.0              0             0
# 4                1.3   91901.0        4.0              0             1
# 5                2.0  160931.0        4.0              0             1
# ...              ...       ...        ...            ...           ...
# 19232            2.0  300000.0        4.0              1             2
# 19233            2.4  161600.0        4.0              2             1
# 19234            2.0  116365.0        4.0              0             1
# 19235            2.0   51258.0        4.0              0             1
# 19236            2.4  186923.0        4.0              0             1
#
# [18704 rows x 11 columns]

# %%
Y
# Out:
# 0        0
# 2        1
# 3        0
# 4        0
# 5        0
#         ..
# 19232    0
# 19233    0
# 19234    0
# 19235    0
# 19236    0
# Name: Wheel, Length: 18704, dtype: int32

# %% [markdown]
# #### Splitting the Training and Test data

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X,Y , test_size= 0.30 ,random_state=25)

# %%
print("x_train =", x_train.shape)
print("x_test =", x_test.shape)
print()
print("y_train =", y_train.shape)
print("y_test =", y_test.shape)
# Out:
# x_train = (13092, 11)
# x_test = (5612, 11)
#
# y_train = (13092,)
# y_test = (5612,)

# %% [markdown]
# #### Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test  = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
logistic_regressor = LogisticRegression()
logistic_regressor.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logistic_regressor.predict(x_test)
lr = pd.DataFrame({'y_test':y_test,'y_pred':y_pred})
lr.head()
# Out:
#        y_test  y_pred
# 15766       0       0
# 18605       0       0
# 7922        0       0
# 9424        1       0
# 6807        0       0

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[5098,   69],
#        [ 380,   65]], dtype=int64)

# %%
tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()

# %%
tn, fp, fn, tp
# Out:
# (5098, 69, 380, 65)

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),fmt='d', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Setting fmt='d' will display the numbers in the confusion matrix as integers without scientific notation.

# %% [markdown]
# #### Evaluation

# %% [markdown]
# ##### Accuracy

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9199928724162509

# %% [markdown]
# ##### auc roc curve

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_test,y_pred)
# Out:
# 0.5663567192837867

# %% [markdown]
# ##### classification report

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      5167
#            1       0.49      0.15      0.22       445
#
#     accuracy                           0.92      5612
#    macro avg       0.71      0.57      0.59      5612
# weighted avg       0.90      0.92      0.90      5612

# %% [markdown]
# Here total number of 1's is 5167 and 0's is 445

# %% [markdown]
# ### Decision Trees

# %%
new_df
# Out:
#          Price  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0      14727.0            32   1234      2010.0         4                 1
# 2       8467.0            21    679      2006.0         3                 0
# 3       4469.0            16    656      2011.0         4                 1
# 4      12172.0            21    679      2014.0         3                 1
# 5      40384.0            23   1297      2016.0         4                 1
# ...        ...           ...    ...         ...       ...               ...
# 19232   8467.0            36    384      2000.0         1                 1
# 19233  16512.0            23   1326      2011.0         9                 1
# 19234  26944.0            23   1433      2010.0         4                 1
# 19235   6619.0             8    455      2007.0         4                 1
# 19236   1223.0            23   1326      2012.0         9                 1
#
#        Fuel type  Engine volume   Mileage  Cylinders  Gear box type  \
# 0              2            3.5  186005.0        4.0              0
# 2              5            1.3  200000.0        4.0              3
# 3              2            2.5  168966.0        4.0              0
# 4              5            1.3   91901.0        4.0              0
# 5              1            2.0  160931.0        4.0              0
# ...          ...            ...       ...        ...            ...
# 19232          0            2.0  300000.0        4.0              1
# 19233          5            2.4  161600.0        4.0              2
# 19234          1            2.0  116365.0        4.0              0
# 19235          1            2.0   51258.0        4.0              0
# 19236          2            2.4  186923.0        4.0              0
#
#        Drive wheels  Doors  Wheel  Airbags
# 0                 0      1      0     12.0
# 2                 1      1      1      2.0
# 3                 0      1      0      0.0
# 4                 1      1      0      4.0
# 5                 1      1      0      4.0
# ...             ...    ...    ...      ...
# 19232             2      0      0      5.0
# 19233             1      1      0      8.0
# 19234             1      1      0      4.0
# 19235             1      1      0      4.0
# 19236             1      1      0     12.0
#
# [18704 rows x 15 columns]

# %% [markdown]
# #### Splitting the Target and Data

# %%
X = new_df.drop(["Price", "Wheel"], axis = 1)
Y = new_df["Wheel"]

# %%
X
# Out:
#        Manufacturer  Model  Prod. year  Category  Leather interior  Fuel type  \
# 0                32   1234      2010.0         4                 1          2
# 2                21    679      2006.0         3                 0          5
# 3                16    656      2011.0         4                 1          2
# 4                21    679      2014.0         3                 1          5
# 5                23   1297      2016.0         4                 1          1
# ...             ...    ...         ...       ...               ...        ...
# 19232            36    384      2000.0         1                 1          0
# 19233            23   1326      2011.0         9                 1          5
# 19234            23   1433      2010.0         4                 1          1
# 19235             8    455      2007.0         4                 1          1
# 19236            23   1326      2012.0         9                 1          2
#
#        Engine volume   Mileage  Cylinders  Gear box type  Drive wheels  Doors  \
# 0                3.5  186005.0        4.0              0             0      1
# 2                1.3  200000.0        4.0              3             1      1
# 3                2.5  168966.0        4.0              0             0      1
# 4                1.3   91901.0        4.0              0             1      1
# 5                2.0  160931.0        4.0              0             1      1
# ...              ...       ...        ...            ...           ...    ...
# 19232            2.0  300000.0        4.0              1             2      0
# 19233            2.4  161600.0        4.0              2             1      1
# 19234            2.0  116365.0        4.0              0             1      1
# 19235            2.0   51258.0        4.0              0             1      1
# 19236            2.4  186923.0        4.0              0             1      1
#
#        Airbags
# 0         12.0
# 2          2.0
# 3          0.0
# 4          4.0
# 5          4.0
# ...        ...
# 19232      5.0
# 19233      8.0
# 19234      4.0
# 19235      4.0
# 19236     12.0
#
# [18704 rows x 13 columns]

# %%
Y
# Out:
# 0        0
# 2        1
# 3        0
# 4        0
# 5        0
#         ..
# 19232    0
# 19233    0
# 19234    0
# 19235    0
# 19236    0
# Name: Wheel, Length: 18704, dtype: int32

# %% [markdown]
# #### Splitting the Training and Test data

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X,Y , test_size= 0.15 ,random_state=52)

# %%
print("x_train =", x_train.shape)
print("x_test =", x_test.shape)
print()
print("y_train =", y_train.shape)
print("y_test =", y_test.shape)
# Out:
# x_train = (15898, 13)
# x_test = (2806, 13)
#
# y_train = (15898,)
# y_test = (2806,)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(x_test)
lr = pd.DataFrame({'y_test':y_test,'y_pred':y_pred})
lr.head()
# Out:
#        y_test  y_pred
# 969         0       0
# 17347       0       0
# 14095       1       1
# 6062        0       0
# 220         1       1

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[2520,   62],
#        [  56,  168]], dtype=int64)

# %%
tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
tn, fp, fn, tp
# Out:
# (2520, 62, 56, 168)

# %%
sns.heatmap(confusion_matrix(y_test,y_pred), fmt='d', annot=True)
plt.show()

# %% [markdown]
# Setting fmt='d' will display the numbers in the confusion matrix as integers without scientific notation.

# %% [markdown]
# #### Evaluation

# %% [markdown]
# ##### Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9579472558802566

# %% [markdown]
# ##### Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2582
#            1       0.73      0.75      0.74       224
#
#     accuracy                           0.96      2806
#    macro avg       0.85      0.86      0.86      2806
# weighted avg       0.96      0.96      0.96      2806

# %% [markdown]
# Here total number of 1's is 2582 and 0's is 224.

# %%
plt.figure(figsize=(40,10))
from sklearn import tree
dtc = tree.DecisionTreeClassifier(max_depth=5)  
dtc.fit(x_train, y_train)
tree.plot_tree(dtc, feature_names = new_df.columns[:-2], class_names=["Left wheel","Right wheel"], filled=True)
plt.show()

# %% [markdown]
# ### Random Forest Model

# %%
new_df
# Out:
#          Price  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0      14727.0            32   1234      2010.0         4                 1
# 2       8467.0            21    679      2006.0         3                 0
# 3       4469.0            16    656      2011.0         4                 1
# 4      12172.0            21    679      2014.0         3                 1
# 5      40384.0            23   1297      2016.0         4                 1
# ...        ...           ...    ...         ...       ...               ...
# 19232   8467.0            36    384      2000.0         1                 1
# 19233  16512.0            23   1326      2011.0         9                 1
# 19234  26944.0            23   1433      2010.0         4                 1
# 19235   6619.0             8    455      2007.0         4                 1
# 19236   1223.0            23   1326      2012.0         9                 1
#
#        Fuel type  Engine volume   Mileage  Cylinders  Gear box type  \
# 0              2            3.5  186005.0        4.0              0
# 2              5            1.3  200000.0        4.0              3
# 3              2            2.5  168966.0        4.0              0
# 4              5            1.3   91901.0        4.0              0
# 5              1            2.0  160931.0        4.0              0
# ...          ...            ...       ...        ...            ...
# 19232          0            2.0  300000.0        4.0              1
# 19233          5            2.4  161600.0        4.0              2
# 19234          1            2.0  116365.0        4.0              0
# 19235          1            2.0   51258.0        4.0              0
# 19236          2            2.4  186923.0        4.0              0
#
#        Drive wheels  Doors  Wheel  Airbags
# 0                 0      1      0     12.0
# 2                 1      1      1      2.0
# 3                 0      1      0      0.0
# 4                 1      1      0      4.0
# 5                 1      1      0      4.0
# ...             ...    ...    ...      ...
# 19232             2      0      0      5.0
# 19233             1      1      0      8.0
# 19234             1      1      0      4.0
# 19235             1      1      0      4.0
# 19236             1      1      0     12.0
#
# [18704 rows x 15 columns]

# %% [markdown]
# #### Splitting the Target and Data

# %%
X = new_df.iloc[:,1:]
Y = new_df['Price']

# %%
X
# Out:
#        Manufacturer  Model  Prod. year  Category  Leather interior  Fuel type  \
# 0                32   1234      2010.0         4                 1          2
# 2                21    679      2006.0         3                 0          5
# 3                16    656      2011.0         4                 1          2
# 4                21    679      2014.0         3                 1          5
# 5                23   1297      2016.0         4                 1          1
# ...             ...    ...         ...       ...               ...        ...
# 19232            36    384      2000.0         1                 1          0
# 19233            23   1326      2011.0         9                 1          5
# 19234            23   1433      2010.0         4                 1          1
# 19235             8    455      2007.0         4                 1          1
# 19236            23   1326      2012.0         9                 1          2
#
#        Engine volume   Mileage  Cylinders  Gear box type  Drive wheels  Doors  \
# 0                3.5  186005.0        4.0              0             0      1
# 2                1.3  200000.0        4.0              3             1      1
# 3                2.5  168966.0        4.0              0             0      1
# 4                1.3   91901.0        4.0              0             1      1
# 5                2.0  160931.0        4.0              0             1      1
# ...              ...       ...        ...            ...           ...    ...
# 19232            2.0  300000.0        4.0              1             2      0
# 19233            2.4  161600.0        4.0              2             1      1
# 19234            2.0  116365.0        4.0              0             1      1
# 19235            2.0   51258.0        4.0              0             1      1
# 19236            2.4  186923.0        4.0              0             1      1
#
#        Wheel  Airbags
# 0          0     12.0
# 2          1      2.0
# 3          0      0.0
# 4          0      4.0
# 5          0      4.0
# ...      ...      ...
# 19232      0      5.0
# 19233      0      8.0
# 19234      0      4.0
# 19235      0      4.0
# 19236      0     12.0
#
# [18704 rows x 14 columns]

# %%
Y
# Out:
# 0        14727.0
# 2         8467.0
# 3         4469.0
# 4        12172.0
# 5        40384.0
#           ...
# 19232     8467.0
# 19233    16512.0
# 19234    26944.0
# 19235     6619.0
# 19236     1223.0
# Name: Price, Length: 18704, dtype: float64

# %% [markdown]
# #### Splitting the Training and Test data

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X,Y , test_size= 0.25 ,random_state=42)

# %%
print("x_train =", x_train.shape)
print("x_test =", x_test.shape)
print()
print("y_train =", y_train.shape)
print("y_test =", y_test.shape)
# Out:
# x_train = (14028, 14)
# x_test = (4676, 14)
#
# y_train = (14028,)
# y_test = (4676,)

# %% [markdown]
# #### Scaling the Data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test  = scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
Rf = RandomForestRegressor(n_estimators = 400,max_depth=15, max_features='log2',random_state=1)
Rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=15, max_features='log2', n_estimators=400,
#                       random_state=1)

# %%
y_pred = Rf.predict(x_test)
y_pred = Rf.predict(x_test)
rf= pd.DataFrame({'y_test':y_test,'y_pred':y_pred})
rf.head()
# Out:
#         y_test        y_pred
# 60     17465.0  15255.540783
# 4640   31389.0  33088.498144
# 2751   15551.0  16122.378051
# 13879  13891.0  17453.181266
# 15200  10171.0   7923.590371

# %% [markdown]
# #### Evaluation

# %%
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
mae = round(mean_absolute_error(y_test, y_pred), 3)
mse = round(mean_squared_error(y_test, y_pred), 3)
rmse = round(np.sqrt(mse), 3)

r2_value = round(r2_score(y_test, y_pred), 3)

print('Mean Absolute Error  of the model is : {}'.format(mae))
print('Mean Squared Error of the model is : {}'.format(mse))
print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
# Out:
# Mean Absolute Error  of the model is : 4368.284
# Mean Squared Error of the model is : 45047806.014
# Root Mean Squared Error of the model is : 6711.766
# R-squared value of the model is : 0.75

# %% [markdown]
# ## Prediction of the Car Price

# %%
print("Welcome to Car Price Predictor!")
print("Fill in the details to estimate the car price.")

Manufacturer = Manufacturer_le.fit_transform([input("Enter the Car Manufacturer Name: ")])
Model = Model_le.fit_transform([input("Enter the Car's Model Name: ")])
Year = int(input("Enter the Year of the car: "))
Category = Category_le.fit_transform([input("Enter the Category of the car: ")])
Interior = int(input("Enter leather interior given(if yes then 1 or no then 0): "))  
Fuel = Fuel_type_le.fit_transform([input("Enter the Car's Fuel type: ")])
Gear_box = Gear_box_type_le.fit_transform([input("Enter the type of gear box in the car: ")])
Mileage = float(input("Enter the Mileage of the car in kilometers: "))
Cylinders = float(input("Enter the number of Cylinders in the car: "))
Engine_volume = float(input("Enter the Engine Volume of the car in liters: "))
Doors = int(input("Enter the number of Doors on the car(if 4-5 then 1 or 2-5 then 0): "))
Drive = Drive_wheels_le.fit_transform([input("Enter the Drive wheels of the car: ")])
Wheel = int(input("Enter the wheel of the car (if left then 0 or right then 1): "))
Airbags = float(input("Enter the Airbags in the car: "))

car_features = [Manufacturer, Model, Year, Category, Interior, Fuel, Gear_box, Mileage, Cylinders, Engine_volume, Doors, Drive, Wheel, Airbags]
predicted_price = Rf.predict([car_features])
print("Estimated Car Price: ${:.2f}".format(predicted_price[0]))
# Out:
# Welcome to Car Price Predictor!
# Fill in the details to estimate the car price.
# Enter the Car Manufacturer Name: HYUNDAI
# Enter the Car's Model Name: Sonata
# Enter the Year of the car: 2016
# Enter the Category of the car: Sedan
# Enter leather interior given(if yes then 1 or no then 0): 1
# Enter the Car's Fuel type: Hybrid
# Enter the type of gear box in the car: Automatic
# Enter the Mileage of the car in kilometers: 50000
# Enter the number of Cylinders in the car: 4.0
# Enter the Engine Volume of the car in liters: 2.3
# Enter the number of Doors on the car(if 4-5 then 1 or 2-5 then 0): 1
# Enter the Drive wheels of the car: Front
# Enter the wheel of the car (if left then 0 or right then 1): 0
# Enter the Airbags in the car: 4.0
# Estimated Car Price: $23476.71

# %% [markdown]
# ### Summary

# %% [markdown]
# • I had done all the Models using target column/variable having both Classification and Regression values.
#
# • The Classification values has been done by the Logistic Regression Model and the Decision Tree Model.
#
# • The Regression values has been done by the Linear Regression Model and the Random Forest Model.
#
# • The main difference between Regression and Classification values is that Regression values are used to predict the      continuous values such as price, salary, age, etc. and Classification values are used to Predict/Classify the discrete values such as Male or Female, True or False, Spam or Not Spam, etc.
#
# • I had used Price as the target column in the Linear Regression Model and the Random Forest Model.
#
# • I had used Wheel as the target column in the Logistic Regression Model and the Decision Tree Model.

# %% [markdown]
# ### Saving in pickle File

# %%
import pickle

# %%
filename = "trained_model.sav"
pickle.dump(Rf, open(filename, 'wb'))

# %%
#loading the save model
loaded_model = pickle.load(open("trained_model.sav", 'rb'))

# %%
with open('manufacturer_encoder.pkl', 'wb') as f:
    pickle.dump(Manufacturer_le, f)

# %%
with open('model_encoder.pkl', 'wb') as f:
    pickle.dump(Model_le, f)

# %%
with open('category_encoder.pkl', 'wb') as f:
    pickle.dump(Category_le, f)

# %%
with open('fuel_type_encoder.pkl', 'wb') as f:
    pickle.dump(Fuel_type_le, f)

# %%
with open('gear_box_encoder.pkl', 'wb') as f:
    pickle.dump(Gear_box_type_le, f)

# %%
with open('drive_wheels_encoder.pkl', 'wb') as f:
    pickle.dump(Drive_wheels_le, f)
